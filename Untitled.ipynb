# %%
# !pip install flask scikit-learn pandas nltk
# Out:
# Running cells with 'Python 3.14.0' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/USER/Desktop/Fake-News-Detection-main - Copy - Copy/.venv/Scripts/python.exe" -m pip install ipykernel -U --user --force-reinstall'
